# %% [markdown]
# #Introduction:

# %% [markdown]
# Ce BE dure 3h environ. Il se termine à 17h05. L'énoncé est réparti dans cinq notebooks différents, dont celui-là. Les exercices sont indépendants et les questions ne sont généralement pas bloquantes.
#
# Les parties 1 et 2 du problème et l'exercice sur la réidentification sont techniquement simples.  L'exercice sur les GANs conditionnels demande un peu plus d'aisance.
# A priori, le problème sera noté sur 12 pts et les exercices comptent chacun pour 4 points.

# %% [markdown]
# **Pour démarrer:**

# %% [markdown]
# - Créer un dossier *BE_prenomNom* sur votre drive. Placez-y tous les énoncés et *utile_BE.py*.
# - partager ce répertoire avec tpdeeplearning@gmail.com (droits d'**édition**, pour la correction).
# - Télécharger les **sept** fichiers utiles sur WeTransfer à l'adresse https://we.tl/t-T29RYcSOTU. Télécharger aussi les deux fichiers à l'adresse https://we.tl/t-wy8RzmjoQv.
# - Les charger ensuite dans un sous-répertoire *BE_prenomNom/data*.

# %% [markdown]
# **Pour terminer:**

# %% [markdown]
# - Fichier/Enregistrer le(s) notebook(s) en cours d'édition
# - Envoyer **tous vos notebooks** par mail à l'adresse tpdeeplearning@gmail.com en précisant vos **nom et prénom** dans le mail.

# %% [markdown]
# Bon courage !
